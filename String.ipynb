# %% [markdown]
# # 5.1 문자열

# %%
#p65
print("hello")         # 'hello'를 출력!
print('hello')         # 'hello'를 출력!
# Out:
# hello
# hello

# %%
print('My friend's house.')
# Out:
#   File "<ipython-input-2-5c19e5fd8ed1>", line 1
#     print('My friend's house.')
#                      ^
# SyntaxError: invalid syntax

# %%
print("My friend's house.")
# Out:
# My friend's house.

# %%
print("그녀가 말했다. "안녕!".")
# Out:
#   File "<ipython-input-4-f5e90ed55b11>", line 1
#     print("그녀가 말했다. "안녕!".")
#                       ^
# SyntaxError: invalid syntax

# %%
com = '안녕하세요!'
print(com[:2])
print(com[-3:])
# Out:
# 안녕
# 세요!

# %%
print('그녀가 말했다. "안녕!"')
# Out:
# 그녀가 말했다. "안녕!"

# %% [markdown]
# ## 문자열 읽어오기

# %%
#p66
animal = 'frog'
print(animal[3])
# Out:
# g

# %%
animal = 'frog'
print(animal[-2])
# Out:
# o

# %%
#p67
animal = '진돗개'
print(animal[0])
print(animal[-2])
# Out:
# 진
# 돗

# %% [markdown]
# ### [TIP] 문자열 슬라이싱

# %%
#p68
animal = 'frog'
print(animal[1])
# Out:
# r

# %%
animal = 'frog'
print(animal[1:3])
# Out:
# ro

# %%
animal = 'frog'
print(animal[0:3:2])
# Out:
# fo

# %%
#p69
animal = 'frog'
print(animal[:])
print(animal[1:])
print(animal[:2])
# Out:
# frog
# rog
# fr

# %%
animal = 'elephant'
print(animal[::2])
print(animal[::-2])
# Out:
# eehn
# tapl

# %% [markdown]
# ## 문자열의 병합

# %%
#p71
dog = '개'
animal = '진돗' + dog
print(animal)
# Out:
# 진돗개

# %% [markdown]
# ## 문자열 함수(메소드)

# %%
animal = 'elephant'
print(len(animal))
# Out:
# 8

# %% [markdown]
# ### 정보 수집

# %%
#p72
animal = 'elephant'
print('총 개수:', animal.count('e'))
# Out:
# 총 개수: 2

# %%
animal = 'elephant'
print('앞쪽 찾기:', animal.find('e'))
print('ep 찾기:', animal.find('ep'))
print('뒤쪽 찾기:', animal.rfind('e'))
print('위치:', animal.index('e'))
print('el 시작:', animal.startswith('el'))
# Out:
# 앞쪽 찾기: 0
# ep 찾기: 2
# 뒤쪽 찾기: 2
# 위치: 0
# el 시작: True

# %%
animal = 'elephant'
print('n이 있다.:', 'n' in animal)
print('an이 있다.:', 'an' in animal)
print('an이 없다.:', 'an' not in animal)
# Out:
# n이 있다.: True
# an이 있다.: True
# an이 없다.: False

# %% [markdown]
# ### 정보 수정

# %%
#p73
ai = 'python program'
print('선택수정:', ai.replace('p', 'P'))
print('소문자:', ai.lower())
print('대문자:', ai.upper())
print('swap대소문자:', ai.swapcase())
print('첫문자만 대문자:', ai.capitalize())
# Out:
# 선택수정: Python Program
# 소문자: python program
# 대문자: PYTHON PROGRAM
# swap대소문자: PYTHON PROGRAM
# 첫문자만 대문자: Python program

# %%
animal = 'Elephant'
animal = animal.upper()
print(animal)
# Out:
# ELEPHANT

# %% [markdown]
# ### 정보 분할

# %%
animal = ' elephant '
print('왼쪽 벗겨내기:', animal.lstrip())
print('오른쪽 벗겨내기:', animal.rstrip())
print('좌우 벗겨내기:', animal.strip())
# Out:
# 왼쪽 벗겨내기: elephant
# 오른쪽 벗겨내기:  elephant
# 좌우 벗겨내기: elephant

# %% [markdown]
# ## [TIP] Random 모듈

# %%
#p74
import random
random.random()
# Out:
# 0.7330234008882273

# %%
import random
print(random.randrange(1, 6))
# Out:
# 2

# %%
import random
chars = '한글우수'
print(random.choice(chars))
# Out:
# 수

# %%
#p75
import random
chars = ['한', '글', '우', '수']
print(random.choice(chars))
# Out:
# 한

# %%
import random
chars = ['한', '글', '우', '수']
random.shuffle(chars)
print(chars)
# Out:
# ['글', '수', '우', '한']

# %%
import random
pw = str()
chars = '한글우수'
for _ in range(5):
    pw = pw + random.choice(chars)
print(pw)
# Out:
# 글한수글글

# %%
a = [1, 2, 3, 4, 5]
a[0::2]
# Out:
# [1, 3, 5]

# %%
all = [1, 2, 3, 4, 5, 6]
for i in all:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
# 6
